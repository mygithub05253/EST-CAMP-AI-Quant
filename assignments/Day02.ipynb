# %% [markdown]
# # 1번
# 다음의 pets 데이터에서 "호랑이" 와 3 을 각각 추출하여 출력해보기 \
# pets = [
#     {"name" : "구름", "age" : 5},
#     {"name" : "초코", "age" : 3},
#     {"name" : "아지", "age" : 1},
#     {"name" : "호랑이", "age" : 2}
# ]

# %%
pets = [
    {"name" : "구름", "age" : 5},
    {"name" : "초코", "age" : 3},
    {"name" : "아지", "age" : 1},
    {"name" : "호랑이", "age" : 2}
]

# %%
print(pets[3]["name"])
# Out:
# 호랑이

# %%
print(pets[1]["age"])
# Out:
# 3

# %% [markdown]
# ## 1번 해설

# %%
# pets 데이터의 type 확인
print(type(pets))
# Out:
# <class 'list'>

# %%
print(pets[3])
# Out:
# {'name': '호랑이', 'age': 2}

# %%
# 리스트 안에 있는 딕셔너리에서 특정 value를 뽑는 방법 : 딕셔너리[위치][키]
print(pets[3]["name"])
# Out:
# 호랑이

# %%
print(pets[1]["age"])
# Out:
# 3
