# %% [markdown]
# # 변수
#
# - 변할 수 있는 자료
# - 값을 저장할 때 사용
#     - 모든 자료형의 값을 저장할 수 있음

# %%
pi = 3.14159265
print(pi)
# Out:
# 3.14159265

# %% [markdown]
# ## 변수 활용 방법
#
# - 변수를 선언
#     - 변수를 생성하는 것
#
# - 변수에 값을 할당
#     - 변수에 값을 넣는 것
#         - = 기호는 우변의 값을 좌변에 할당하겠다는 의미
#
# - 변수를 참조
#     - 변수에서 값을 꺼내는 것

# %%
print(pi + 2)
# Out:
# 5.14159265

# %% [markdown]
# # 복합 대입 연산자
#
# - 자료형에 적용하는 기본 연산자와 = 연산자를 함께 사용해 구성하는 연산자
#     - += : 숫자 덧셈 후 대입
#     - -= : 숫자 뺄셈 후 대입
#     - *= : 숫자 곱셈 후 대입
#     - /= : 숫자 나눗셈 후 대입
#     - %= : 숫자 나머지를 구한 후 대입
#     - **= : 숫자 제곱 후 대입
#
# - 예) a += 10은 a = a + 10과 같은 결과

# %%
number = 100 # 100
number += 10 # 110
number += 20 # 130

print(number)
# Out:
# 130

# %%
# 문자열 복합 대입 연산자
str1 = "안녕하세요" # 안녕하세요
str1 += "!" # 안녕하세요!
str1 += "!" # 안녕하세요!!

print(str1)
# Out:
# 안녕하세요!!

# %% [markdown]
# # 자료형 변환

# %% [markdown]
# ## 문자열을 숫자로 변환하기
#
# - int() : 문자열을 int 자료형으로 변환
# - float() : 문자열을 float 자료형으로 변환

# %%
str_a = "273"
int_a = int(str_a)

str_b = "52"
int_b = int(str_b)

print(str_a + str_b) # 27352
print(int_a + int_b) # 325
# Out:
# 27352
# 325

# %%
output_a = int("52")
output_b = float("52.273")

print(type(output_a), output_a)
print(type(output_b), output_b)
# Out:
# <class 'int'> 52
# <class 'float'> 52.273

# %%
input_a = float("273")
input_b = float("52")

print(input_a + input_b)
# Out:
# 325.0

# %% [markdown]
# - 자료형을 변환할 때 "변환할 수 없는 것"을 변환하려고 하면 ValueError 예외가 발생
#     - 숫자 아닌 것을 숫자로 변환하려고 하는 경우
#     - 소수점이 있는 숫자 형식의 문자열을 int() 함수로 변환하려고 하는 경우

# %%
int(273.5)
# Out:
# 273

# %%
# 문자열은 숫자로 변환할 수 없음
print(int("안녕하세요"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 2
#       1 # 문자열은 숫자로 변환할 수 없음
# ----> 2 print(int("안녕하세요"))
#
# ValueError: invalid literal for int() with base 10: '안녕하세요'

# %%
# 부동소수점이 있는 숫자 형식의 문자열을 숫자로 변환할 수 없음
int("273.5")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 2
#       1 # 부동소수점이 있는 숫자 형식의 문자열을 숫자로 변환할 수 없음
# ----> 2 int("273.5")
#
# ValueError: invalid literal for int() with base 10: '273.5'

# %%
float("273.5")
# Out:
# 273.5

# %% [markdown]
# ## 다른 자료형을 문자열로 변경하기
#
# - str() : 문자열로 변환

# %%
output_a = str(52)
output_b = str(52.273)

print(type(output_a), output_a)
print(type(output_b), output_b)
# Out:
# <class 'str'> 52
# <class 'str'> 52.273
